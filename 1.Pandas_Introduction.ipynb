# %%
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-a36fa161-f3a5-4c62-8d8e-dd4e021471a2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a36fa161-f3a5-4c62-8d8e-dd4e021471a2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv("Salaries (3).csv")

# %%
data
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
data.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %% [markdown]
# Gives first five(default) rows

# %%
data.head
# Out:
# <bound method NDFrame.head of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %% [markdown]
# Does not give the same output without parantheses

# %%
data.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %% [markdown]
# We can give a number inside the parantheses to get first 10 or 20 or any no of rows

# %%
data.tail
# Out:
# <bound method NDFrame.tail of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
data.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %% [markdown]
# Gives last 5 rows

# %%
data.tail(15)
# Out:
#          rank discipline  phd  service     sex  salary
# 63       Prof          A   29       27  Female   91000
# 64  AssocProf          A   26       24  Female   73300
# 65       Prof          A   36       19  Female  117555
# 66   AsstProf          A    7        6  Female   63100
# 67       Prof          A   17       11  Female   90450
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
data.sample()
# Out:
#     rank discipline  phd  service   sex  salary
# 36  Prof          B   45       45  Male  146856

# %% [markdown]
# gives any one random row(record)

# %%
data.sample
# Out:
# <bound method NDFrame.sample of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
data.sample(5)
# Out:
#          rank discipline  phd  service     sex  salary
# 33       Prof          B   18       18    Male  120000
# 21       Prof          A   33       30    Male  103106
# 59  AssocProf          B   12       10  Female  103994
# 51       Prof          B   20       14  Female  127512
# 10       Prof          B   39       33    Male  128250

# %% [markdown]
# Gives 5 random rows without any order

# %%
data.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %% [markdown]
# Data type of all columns

# %%
data['service'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Data type of single column

# %%
data[['service','sex']].dtypes
# Out:
# service     int64
# sex        object
# dtype: object

# %% [markdown]
# Data type of more than one column

# %%
data["salary"].dtype
# Out:
# dtype('int64')

# %%
data.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
data.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
data.shape
# Out:
# (78, 6)

# %% [markdown]
# Return a tuple representing the dimensionality(rows,columns)

# %%
data.ndim
# Out:
# 2

# %% [markdown]
# Number of dimensions

# %%
data.size
# Out:
# 468

# %% [markdown]
# Number of elements

# %%
data.values
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %%
data.shape[0]
# Out:
# 78

# %% [markdown]
# Gives only no of records

# %%
data.shape[1]
# Out:
# 6

# %% [markdown]
# Gives only no of columns

# %%
len(data)
# Out:
# 78

# %% [markdown]
# Gives no of records

# %%
data.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %% [markdown]
# Shows descriptive statistics for numerical columns
# Gives summary for the numerical columns in dataset

# %%
data.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
data['salary'].max()
# Out:
# 186960

# %%
data.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
data['salary'].min()
# Out:
# 57800

# %%
data.mean()
# Out:
# <ipython-input-39-abc01cf6c622>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
data['salary'].mean()
# Out:
# 108023.78205128205

# %%
data.median()
# Out:
# <ipython-input-41-135339ac59ce>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# phd            18.5
# service        14.5
# salary     104671.0
# dtype: float64

# %%
data['salary'].median()
# Out:
# 104671.0

# %%
data.std()
# Out:
# <ipython-input-43-a47ac8255c06>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.std()
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
data['salary'].std()
# Out:
# 28293.66102226417

# %%
data.head(50).mean()
# Out:
# <ipython-input-46-6a037781b7b4>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.head(50).mean()
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %% [markdown]
# Mean values of first 50 records

# %%
data.tail(20).min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   3
# service               2
# sex              Female
# salary            63100
# dtype: object

# %% [markdown]
# Gives min value of all columns from last 20 records

# %%
a=data.head(50)
a.mean()
# Out:
# <ipython-input-48-1ffec17baf7c>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.mean()
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
data['salary'].mean()
# Out:
# 108023.78205128205

# %%
data[['service','phd']].max()
# Out:
# service    51
# phd        56
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
data.info
# Out:
# <bound method DataFrame.info of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
data.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
data.rank
# Out:
# <bound method NDFrame.rank of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
data['rank']
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
data[['rank','sex']]
# Out:
#          rank     sex
# 0        Prof    Male
# 1        Prof    Male
# 2        Prof    Male
# 3        Prof    Male
# 4        Prof    Male
# ..        ...     ...
# 73       Prof  Female
# 74  AssocProf  Female
# 75       Prof  Female
# 76       Prof  Female
# 77       Prof  Female
#
# [78 rows x 2 columns]

# %%
data['phd'].mean()
# Out:
# 19.705128205128204

# %%
data['phd'].median()
# Out:
# 18.5

# %%
data['phd'].mode()
# Out:
# 0    4
# Name: phd, dtype: int64

# %%
data['phd'].describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %% [markdown]
# Calculate the basic statistics of phd column

# %%
data['phd'].count()
# Out:
# 78

# %%
len(data['phd'])
# Out:
# 78

# %%
len(data.phd)
# Out:
# 78

# %%
data['rank'].unique()
# Out:
# array(['Prof', 'AssocProf', 'AsstProf'], dtype=object)

# %% [markdown]
# Gives the unique values of that column(can be applied only for categorical columns)

# %%
data['sex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data['discipline'].unique()
# Out:
# array(['B', 'A'], dtype=object)

# %%
data['discipline'].nunique()
# Out:
# 2

# %% [markdown]
# No. of unique values

# %%
data['sex'].nunique()
# Out:
# 2

# %%
data['rank'].nunique()
# Out:
# 3

# %%
data['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %% [markdown]
# Gives the no of each unique values in that coulumn

# %%
data['discipline'].value_counts()
# Out:
# B    42
# A    36
# Name: discipline, dtype: int64

# %%
data['sex'].value_counts()
# Out:
# Male      39
# Female    39
# Name: sex, dtype: int64

# %%
data.groupby('rank').mean()
# Out:
# <ipython-input-34-a6331444cb10>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('rank').mean()
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %% [markdown]
# Group by method can only be done on categorical columns

# %%
a=data.groupby('rank').mean()
# Out:
# <ipython-input-37-24f8945f8782>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a=data.groupby('rank').mean()

# %%
a=data.groupby('rank')
a.mean()
# Out:
# <ipython-input-38-b814629cec11>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a.mean()
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
a['salary'].mean()
# Out:
# rank
# AssocProf     91786.230769
# AsstProf      81362.789474
# Prof         123624.804348
# Name: salary, dtype: float64

# %%
a[['salary','phd']].mean()
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
data.groupby('sex').mean()
# Out:
# <ipython-input-41-bd2cd7c2fcdf>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('sex').mean()
#               phd    service         salary
# sex
# Female  16.512821  11.564103  101002.410256
# Male    22.897436  18.538462  115045.153846

# %%
data.groupby('discipline').mean()
# Out:
# <ipython-input-42-405f98d43a8f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('discipline').mean()
#                   phd    service         salary
# discipline
# A           21.527778  15.722222   98331.111111
# B           18.142857  14.476190  116331.785714

# %%
data.groupby('sex')['salary'].mean()
# Out:
# sex
# Female    101002.410256
# Male      115045.153846
# Name: salary, dtype: float64

# %%
data.groupby('sex')[['salary','phd']].mean()
# Out:
#                salary        phd
# sex
# Female  101002.410256  16.512821
# Male    115045.153846  22.897436

# %% [markdown]
# Calculate avg salary and avg phd for male and female employees

# %%
data.groupby('discipline')['salary'].max()
# Out:
# discipline
# A    155865
# B    186960
# Name: salary, dtype: int64

# %% [markdown]
# Calculate max salary for both disciplines

# %%
data.groupby(['sex','discipline'])[['salary','phd']].mean()
# Out:
#                           salary        phd
# sex    discipline
# Female A            89064.944444  17.500000
#        B           111234.523810  15.666667
# Male   A           107597.277778  25.555556
#        B           121429.047619  20.619048

# %% [markdown]
# Calculate avg salary and avg phd for male and female employees in discipline A and B

# %%
data.groupby(['sex','discipline','rank'])[['salary','phd','service']].mean()
# Out:
#                                     salary        phd    service
# sex    discipline rank
# Female A          AssocProf   72128.500000  18.500000  15.500000
#                   AsstProf    72933.333333   4.833333   2.500000
#                   Prof       109631.875000  26.500000  16.125000
#        B          AssocProf   99435.666667  13.500000   8.833333
#                   AsstProf    84189.800000   6.600000   2.600000
#                   Prof       131836.200000  21.500000  17.900000
# Male   A          AssocProf   81285.000000  20.000000  17.000000
#                   AsstProf    79000.000000   3.000000   1.000000
#                   Prof       113164.400000  28.933333  22.733333
#        B          AssocProf  113404.000000  10.500000   7.500000
#                   AsstProf    88224.000000   4.666667   2.000000
#                   Prof       137989.076923  29.538462  25.846154

# %%
data.groupby(['discipline','rank'])['service'].max()
# Out:
# discipline  rank
# A           AssocProf    24
#             AsstProf      6
#             Prof         51
# B           AssocProf    11
#             AsstProf      5
#             Prof         49
# Name: service, dtype: int64

# %%
data.groupby(['sex','discipline','rank'])[['salary','phd','service']].describe()
# Out:
#                             salary                                         \
#                              count           mean           std       min
# sex    discipline rank
# Female A          AssocProf    4.0   72128.500000   6402.715752   62884.0
#                   AsstProf     6.0   72933.333333   5463.210289   63100.0
#                   Prof         8.0  109631.875000  15094.589044   90450.0
#        B          AssocProf    6.0   99435.666667  14086.475509   71065.0
#                   AsstProf     5.0   84189.800000   9792.119188   74692.0
#                   Prof        10.0  131836.200000  17504.273985  105450.0
# Male   A          AssocProf    1.0   81285.000000           NaN   81285.0
#                   AsstProf     2.0   79000.000000   8485.281374   73000.0
#                   Prof        15.0  113164.400000  26382.613222   57800.0
#        B          AssocProf    2.0  113404.000000   9045.309945  107008.0
# ...

# %%
data['sex'].value_counts()
# Out:
# Male      39
# Female    39
# Name: sex, dtype: int64

# %% [markdown]
# How many male and female employees are there

# %%
len(data.groupby(['sex']))
# Out:
# 2

# %%
data.groupby('discipline').mean()
# Out:
# <ipython-input-67-405f98d43a8f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('discipline').mean()
#                   phd    service         salary
# discipline
# A           21.527778  15.722222   98331.111111
# B           18.142857  14.476190  116331.785714

# %% [markdown]
# calculate avg salary for both disciplines

# %%
data['phd'].max()
# Out:
# 56

# %% [markdown]
# Calculate max phd

# %%
data['service'].std()
# Out:
# 12.139767682042327

# %% [markdown]
# calculate standrad deviation for service

# %%
data[['salary','phd']].agg(['min','max'])
# Out:
#      salary  phd
# min   57800    1
# max  186960   56

# %% [markdown]
# aggregate function is used when multiple statistics are to be done

# %%
data[['salary','phd']].describe()
# Out:
#               salary        phd
# count      78.000000  78.000000
# mean   108023.782051  19.705128
# std     28293.661022  12.498425
# min     57800.000000   1.000000
# 25%     88612.500000  10.250000
# 50%    104671.000000  18.500000
# 75%    126774.750000  27.750000
# max    186960.000000  56.000000

# %% [markdown]
# We can use this to check our answers

# %%
data[['salary','phd']].agg(['count','sum','prod'])
# Out:
#         salary   phd
# count       78    78
# sum    8425855  1537
# prod         0     0

# %%
data[['salary','phd']].agg(['mean','median'])
# Out:
#                salary        phd
# mean    108023.782051  19.705128
# median  104671.000000  18.500000

# %%
data[['salary','phd']].agg(['std','var'])
# Out:
#            salary         phd
# std  2.829366e+04   12.498425
# var  8.005313e+08  156.210623

# %%
data.iloc[2]
# Out:
# rank            Prof
# discipline         A
# phd               23
# service           20
# sex             Male
# salary        110515
# Name: 2, dtype: object

# %% [markdown]
# gives 2nd row

# %%
data.iloc[2,5]
# Out:
# 110515

# %% [markdown]
# gives 2nd row 5th column value

# %%
data.iloc[:]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %% [markdown]
# gives all rows and columns(same as data.iloc[:,:])

# %%
data.iloc[:,2]
# Out:
# 0     56
# 1     12
# 2     23
# 3     40
# 4     20
#       ..
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, Length: 78, dtype: int64

# %% [markdown]
# gives all rows 2nd column values

# %%
data.iloc[:20]
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %%
data.iloc[:3,4]
# Out:
# 0    Male
# 1    Male
# 2    Male
# Name: sex, dtype: object

# %%
data.iloc[1:8,1:4]
# Out:
#   discipline  phd  service
# 1          A   12        6
# 2          A   23       20
# 3          A   40       31
# 4          B   20       18
# 5          A   20       20
# 6          A   20       17
# 7          A   18       18

# %%
data.iloc[4:]
# Out:
#          rank discipline  phd  service     sex  salary
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [74 rows x 6 columns]

# %%
data.iloc[:4]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205

# %%
data.iloc[6,:5]
# Out:
# rank          AssocProf
# discipline            A
# phd                  20
# service              17
# sex                Male
# Name: 6, dtype: object

# %%
data.iloc[4:19,4:]
# Out:
#      sex  salary
# 4   Male  104800
# 5   Male  122400
# 6   Male   81285
# 7   Male  126300
# 8   Male   94350
# 9   Male   57800
# 10  Male  128250
# 11  Male  134778
# 12  Male   88000
# 13  Male  162200
# 14  Male  153750
# 15  Male  150480
# 16  Male   75044
# 17  Male   92000
# 18  Male  107300

# %%
data.iloc[4:19,:4]
# Out:
#          rank discipline  phd  service
# 4        Prof          B   20       18
# 5        Prof          A   20       20
# 6   AssocProf          A   20       17
# 7        Prof          A   18       18
# 8        Prof          A   29       19
# 9        Prof          A   51       51
# 10       Prof          B   39       33
# 11       Prof          B   23       23
# 12   AsstProf          B    1        0
# 13       Prof          B   35       33
# 14       Prof          B   25       19
# 15       Prof          B   17        3
# 16   AsstProf          B    8        3
# 17   AsstProf          B    4        0
# 18       Prof          A   19        7

# %%
data.iloc[:4]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205

# %%
data.iloc[2,4]
# Out:
# 'Male'

# %%
data.iloc[3:21]
# Out:
#          rank discipline  phd  service   sex  salary
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# 17   AsstProf          B    4        0  Male   92000
# 18       Prof          A   19        7  Male  107300
# 19       Prof          A   29       27  Male  150500
# ...

# %%
data.iloc[:,3]
# Out:
# 0     49
# 1      6
# 2     20
# 3     31
# 4     18
#       ..
# 73    10
# 74     6
# 75    17
# 76    14
# 77    15
# Name: service, Length: 78, dtype: int64

# %%
data.iloc[7]
# Out:
# rank            Prof
# discipline         A
# phd               18
# service           18
# sex             Male
# salary        126300
# Name: 7, dtype: object

# %%
data.iloc[3:8,2:]
# Out:
#    phd  service   sex  salary
# 3   40       31  Male  131205
# 4   20       18  Male  104800
# 5   20       20  Male  122400
# 6   20       17  Male   81285
# 7   18       18  Male  126300

# %%
data.iloc[:,3]
# Out:
# 0     49
# 1      6
# 2     20
# 3     31
# 4     18
#       ..
# 73    10
# 74     6
# 75    17
# 76    14
# 77    15
# Name: service, Length: 78, dtype: int64

# %%
data.iloc[1,2]
# Out:
# 12

# %%
data.iloc[:,1:5]
# Out:
#    discipline  phd  service     sex
# 0           B   56       49    Male
# 1           A   12        6    Male
# 2           A   23       20    Male
# 3           A   40       31    Male
# 4           B   20       18    Male
# ..        ...  ...      ...     ...
# 73          B   18       10  Female
# 74          B   19        6  Female
# 75          B   17       17  Female
# 76          A   28       14  Female
# 77          A   23       15  Female
#
# [78 rows x 4 columns]

# %%
data.iloc[[2,7],[2,4,5]]
# Out:
#    phd   sex  salary
# 2   23  Male  110515
# 7   18  Male  126300

# %%
data.iloc[[2,7],:]
# Out:
#    rank discipline  phd  service   sex  salary
# 2  Prof          A   23       20  Male  110515
# 7  Prof          A   18       18  Male  126300

# %%
data.iloc[[2,7],[2,5]]
# Out:
#    phd  salary
# 2   23  110515
# 7   18  126300

# %%
data.iloc[[2,3,6,8,10,29],[1,3,5]]
# Out:
#    discipline  service  salary
# 2           A       20  110515
# 3           A       31  131205
# 6           A       17   81285
# 8           A       19   94350
# 10          B       33  128250
# 29          B       20  123683

# %%
data.iloc[[2,3,4,7,9,10,76],0:5]
# Out:
#     rank discipline  phd  service     sex
# 2   Prof          A   23       20    Male
# 3   Prof          A   40       31    Male
# 4   Prof          B   20       18    Male
# 7   Prof          A   18       18    Male
# 9   Prof          A   51       51    Male
# 10  Prof          B   39       33    Male
# 76  Prof          A   28       14  Female

# %%
data.iloc[[-76,-75,-74,-71,-69,-68,-2],-6:-1]
# Out:
#     rank discipline  phd  service     sex
# 2   Prof          A   23       20    Male
# 3   Prof          A   40       31    Male
# 4   Prof          B   20       18    Male
# 7   Prof          A   18       18    Male
# 9   Prof          A   51       51    Male
# 10  Prof          B   39       33    Male
# 76  Prof          A   28       14  Female

# %%
data.iloc[:,0:-4]
# Out:
#          rank discipline
# 0        Prof          B
# 1        Prof          A
# 2        Prof          A
# 3        Prof          A
# 4        Prof          B
# ..        ...        ...
# 73       Prof          B
# 74  AssocProf          B
# 75       Prof          B
# 76       Prof          A
# 77       Prof          A
#
# [78 rows x 2 columns]

# %%
data[data['sex']=='Male']
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %%
data['sex']=='Male'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#       ...
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# Name: sex, Length: 78, dtype: bool

# %%
data[data['salary']>150000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 27  Prof          A   45       43    Male  155865
# 31  Prof          B   22       21    Male  155750
# 44  Prof          B   23       19  Female  151768
# 72  Prof          B   24       15  Female  161101

# %%
data[data['rank']=='AssocProf']
# Out:
#          rank discipline  phd  service     sex  salary
# 6   AssocProf          A   20       17    Male   81285
# 30  AssocProf          B    9        7    Male  107008
# 34  AssocProf          B   12        8    Male  119800
# 41  AssocProf          A   13        8  Female   74830
# 47  AssocProf          B   11       11  Female  103613
# 54  AssocProf          A   25       22  Female   62884
# 56  AssocProf          A   10        8  Female   77500
# 59  AssocProf          B   12       10  Female  103994
# 61  AssocProf          B   13       10  Female  103750
# 62  AssocProf          B   14        7  Female  109650
# 64  AssocProf          A   26       24  Female   73300
# 71  AssocProf          B   12        9  Female   71065
# 74  AssocProf          B   19        6  Female  104542

# %%
len(data[data['discipline']=='B'])
# Out:
# 42

# %%
data[data['sex']=='Male']['salary'].mean()
# Out:
# 115045.15384615384

# %%
data[data['rank']=='Prof']['salary'].agg(['max','min'])
# Out:
# max    186960
# min     57800
# Name: salary, dtype: int64

# %%
data.groupby('rank')['salary'].agg(['max','min'])
# Out:
#               max    min
# rank
# AssocProf  119800  62884
# AsstProf    97032  63100
# Prof       186960  57800

# %%
len(data[data['rank']=='AsstProf']['salary']<100000)
# Out:
# 19

# %%
data[data['discipline']=='B'][['salary','phd']].min()
# Out:
# salary    71065
# phd           1
# dtype: int64

# %%
len(data[(data['rank']=='AsstProf')&(data['salary']<100000)])
# Out:
# 19

# %%
len(data[(data['rank']=='Prof')&(data['salary']<100000)&(data['sex']=='Male')])
# Out:
# 5

# %%
data[(data["sex"]=="Female")&(data["rank"]=="AssocProf")&(data["salary"]>80000)]['salary'].mean()
# Out:
# 105109.8

# %%
data[(data["sex"]=="Male")&(data["discipline"]=="B")][['service','phd']].max()
# Out:
# service    49
# phd        56
# dtype: int64

# %%
len(data[(data["rank"]=="AsstProf")&(data["discipline"]=="A")])
# Out:
# 8

# %%
len(data[data['sex']=='Male']["discipline"]=="B")
# Out:
# 39

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df=scaler.fit_transform(data[["phd","salary","service"]])

# %%
df
# Out:
# array([[ 2.92275171,  2.8079483 ,  2.81458871],
#        [-0.6204782 , -0.53443152, -0.75041527],
#        [ 0.26532928,  0.08861852,  0.4102837 ],
#        [ 1.63430447,  0.82461085,  1.32226146],
#        [ 0.02374542, -0.11467757,  0.24446956],
#        [ 0.02374542,  0.51139613,  0.4102837 ],
#        [ 0.02374542, -0.95116183,  0.16156249],
#        [-0.13731048,  0.65012837,  0.24446956],
#        [ 0.74849699, -0.48640883,  0.32737663],
#        [ 2.52011195, -1.78657892,  2.98040285],
#        [ 1.55377652,  0.71949449,  1.4880756 ],
#        [ 0.26532928,  0.95171092,  0.65900491],
#        [-1.50628568, -0.71229337, -1.24785768],
#        [ 1.23166471,  1.92717643,  1.4880756 ],
#        [ 0.42638518,  1.62658991,  0.32737663],
#        [-0.21783844,  1.51026827, -0.99913648],
#        [-0.94259001, -1.17316899, -0.99913648],
#        [-1.26470182, -0.57000389, -1.24785768],
#        [-0.05678253, -0.02574664, -0.6675082 ],
#        [ 0.74849699,  1.51097971,  0.99063319],
# ...
